# %%
import numpy as np
import pandas as pd

# Load the Parkinson's Disease dataset
# Load the Parkinson's Disease dataset
df = pd.read_csv('pd_speech_features.csv')

# Data cleaning
df = df.drop('id', axis=1)  # Remove the 'name' column

# Data preprocessing
X = df.drop('class', axis=1)  # Features
Y = df['class']  # Target variable

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
import warnings
from sklearn.metrics import confusion_matrix
warnings.filterwarnings("ignore")
from sklearn.preprocessing import MinMaxScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression,RidgeClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

models = [DecisionTreeClassifier(random_state=0),GaussianNB(),KNeighborsClassifier(n_neighbors=5),LogisticRegression(), SVC(),RidgeClassifier()]

# X_train = MinMaxScaler().fit_transform(X_train)
# X_test = MinMaxScaler().fit_transform(X_test)

for model in models:
    model.fit(X_train.values, Y_train.values)
    Y_pred = model.predict(X_test.values)
    tn, fp, fn, tp = confusion_matrix(Y_test, Y_pred).ravel()

    accuracy = (tp + tn) / (tp + tn + fp + fn)
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    precision = tp / (tp + fp)
    npv = tn / (tn + fn)
    fpr = fp / (fp + tn)

    print(f"Metrics for {type(model).__name__}:")
    print(f"Accuracy: {accuracy}")
    print(f"Sensitivity: {sensitivity}")
    print(f"Specificity: {specificity}")
    print(f"Precision: {precision}")
    print(f"NPV: {npv}")
    print(f"FPR: {fpr}\n")
# Out:
# Metrics for DecisionTreeClassifier:
# Accuracy: 0.8157894736842105
# Sensitivity: 0.8771929824561403
# Specificity: 0.631578947368421
# Precision: 0.8771929824561403
# NPV: 0.631578947368421
# FPR: 0.3684210526315789
#
# Metrics for GaussianNB:
# Accuracy: 0.7302631578947368
# Sensitivity: 0.8333333333333334
# Specificity: 0.42105263157894735
# Precision: 0.811965811965812
# NPV: 0.45714285714285713
# FPR: 0.5789473684210527
#
# Metrics for KNeighborsClassifier:
# Accuracy: 0.756578947368421
# Sensitivity: 0.8859649122807017
# Specificity: 0.3684210526315789
# Precision: 0.808
# NPV: 0.5185185185185185
# FPR: 0.631578947368421
#
# Metrics for LogisticRegression:
# Accuracy: 0.7763157894736842
# Sensitivity: 0.9824561403508771
# Specificity: 0.15789473684210525
# Precision: 0.7777777777777778
# NPV: 0.75
# FPR: 0.8421052631578947
#
# Metrics for SVC:
# Accuracy: 0.7763157894736842
# Sensitivity: 0.9912280701754386
# Specificity: 0.13157894736842105
# Precision: 0.773972602739726
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4, random_state=0)

# %%
import warnings
from sklearn.metrics import confusion_matrix
warnings.filterwarnings("ignore")
from sklearn.preprocessing import MinMaxScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression,RidgeClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

models = [DecisionTreeClassifier(random_state=0),GaussianNB(),KNeighborsClassifier(n_neighbors=5),LogisticRegression(), SVC(),RidgeClassifier()]

# X_train = MinMaxScaler().fit_transform(X_train)
# X_test = MinMaxScaler().fit_transform(X_test)

for model in models:
    model.fit(X_train.values, Y_train.values)
    Y_pred = model.predict(X_test.values)
    tn, fp, fn, tp = confusion_matrix(Y_test, Y_pred).ravel()

    accuracy = (tp + tn) / (tp + tn + fp + fn)
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    precision = tp / (tp + fp)
    npv = tn / (tn + fn)
    fpr = fp / (fp + tn)

    print(f"Metrics for {type(model).__name__}:")
    print(f"Accuracy: {accuracy}")
    print(f"Sensitivity: {sensitivity}")
    print(f"Specificity: {specificity}")
    print(f"Precision: {precision}")
    print(f"NPV: {npv}")
    print(f"FPR: {fpr}\n")
# Out:
# Metrics for DecisionTreeClassifier:
# Accuracy: 0.7887788778877888
# Sensitivity: 0.8326180257510729
# Specificity: 0.6428571428571429
# Precision: 0.8858447488584474
# NPV: 0.5357142857142857
# FPR: 0.35714285714285715
#
# Metrics for GaussianNB:
# Accuracy: 0.7260726072607261
# Sensitivity: 0.8369098712446352
# Specificity: 0.35714285714285715
# Precision: 0.8125
# NPV: 0.3968253968253968
# FPR: 0.6428571428571429
#
# Metrics for KNeighborsClassifier:
# Accuracy: 0.7491749174917491
# Sensitivity: 0.8497854077253219
# Specificity: 0.4142857142857143
# Precision: 0.8284518828451883
# NPV: 0.453125
# FPR: 0.5857142857142857
#
# Metrics for LogisticRegression:
# Accuracy: 0.7656765676567657
# Sensitivity: 0.9399141630901288
# Specificity: 0.18571428571428572
# Precision: 0.7934782608695652
# NPV: 0.48148148148148145
# FPR: 0.8142857142857143
#
# Metrics for SVC:
# Accuracy: 0.7656765676567657
# Sensitivity: 0.9313304721030042
# Specificity: 0.21428571428571427
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4, random_state=0)

# %%
import warnings
from sklearn.metrics import confusion_matrix
warnings.filterwarnings("ignore")
from sklearn.preprocessing import MinMaxScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression,RidgeClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn import linear_model

from sklearn.metrics import accuracy_score


models = [DecisionTreeClassifier(random_state=0),GaussianNB(),KNeighborsClassifier(n_neighbors=5),LogisticRegression(), SVC(),RidgeClassifier()]

# X_train = MinMaxScaler().fit_transform(X_train)
# X_test = MinMaxScaler().fit_transform(X_test)
table=[]
columns = ['Model', 'Accuracy', 'Sensitivity', 'Specificity', 'Precision', 'NPV', 'FPR']

for model in models:
    model.fit(X_train.values, Y_train.values)
    Y_pred = model.predict(X_test.values)
    tn, fp, fn, tp = confusion_matrix(Y_test, Y_pred).ravel()

    accuracy = (tp + tn) / (tp + tn + fp + fn)
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    precision = tp / (tp + fp)
    npv = tn / (tn + fn)
    fpr = fp / (fp + tn)

    print(f"Metrics for {type(model).__name__}:")
    print(f"Accuracy: {accuracy}")
    print(f"Sensitivity: {sensitivity}")
    print(f"Specificity: {specificity}")
    print(f"Precision: {precision}")
    print(f"NPV: {npv}")
    print(f"FPR: {fpr}\n")
    
    table.append([type(model).__name__, accuracy, sensitivity, specificity, precision, npv, fpr])

table=pd.DataFrame(table, columns=columns)
table.to_csv('60-40.csv', index=False)
# Out:
# Metrics for DecisionTreeClassifier:
# Accuracy: 0.7887788778877888
# Sensitivity: 0.8326180257510729
# Specificity: 0.6428571428571429
# Precision: 0.8858447488584474
# NPV: 0.5357142857142857
# FPR: 0.35714285714285715
#
# Metrics for GaussianNB:
# Accuracy: 0.7260726072607261
# Sensitivity: 0.8369098712446352
# Specificity: 0.35714285714285715
# Precision: 0.8125
# NPV: 0.3968253968253968
# FPR: 0.6428571428571429
#
# Metrics for KNeighborsClassifier:
# Accuracy: 0.7491749174917491
# Sensitivity: 0.8497854077253219
# Specificity: 0.4142857142857143
# Precision: 0.8284518828451883
# NPV: 0.453125
# FPR: 0.5857142857142857
#
# Metrics for LogisticRegression:
# Accuracy: 0.7656765676567657
# Sensitivity: 0.9399141630901288
# Specificity: 0.18571428571428572
# Precision: 0.7934782608695652
# NPV: 0.48148148148148145
# FPR: 0.8142857142857143
#
# Metrics for SVC:
# Accuracy: 0.7656765676567657
# Sensitivity: 0.9313304721030042
# Specificity: 0.21428571428571427
# ...
